# %%
#importing warnings.

import warnings
warnings.filterwarnings("ignore")

# %%
#importing useful libraries for analysis.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#loading the data.

df= pd.read_csv("TikTok_songs_2020.csv")

#displaying the first 5 rows of the data.

df.head()
# Out:
#                          track_name          artist_name  artist_pop  \
# 0                            Say So             Doja Cat          88
# 1                   Blinding Lights           The Weeknd          93
# 2  Supalonely (feat. Gus Dapperton)                BENEE          67
# 3                            Savage  Megan Thee Stallion          82
# 4                Moral of the Story                 Ashe          68
#
#                 album  track_pop  danceability  energy  loudness  mode  key  \
# 0            Hot Pink         80         0.787   0.673    -4.583     0   11
# 1         After Hours         90         0.514   0.730    -5.934     1    1
# 2             Hey u x         63         0.862   0.631    -4.746     1    7
# 3                Suga         70         0.843   0.741    -5.609     1   11
# 4  Moral of the Story         76         0.572   0.406    -8.624     1   10
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
#displaying the last 5 rows of the data.

df.tail()
# Out:
#                        track_name               artist_name  artist_pop  \
# 287                       Buttons        The Pussycat Dolls          68
# 288                      Get Busy                 Sean Paul          79
# 289  ROCKSTAR (feat. Roddy Ricch)                    DaBaby          82
# 290                      Who Says  Selena Gomez & The Scene          67
# 291               Crystal Dolphin                 Engelwood          50
#
#                       album  track_pop  danceability  energy  loudness  mode  \
# 287                     PCD         65         0.570   0.821    -4.380     1
# 288              Dutty Rock         74         0.735   0.824    -4.143     0
# 289        BLAME IT ON BABY         80         0.746   0.690    -7.956     1
# 290  When The Sun Goes Down         76         0.682   0.927    -2.915     1
# 291                Crust FM         60         0.558   0.776    -6.868     1
#
# ...

# %%
# checking how many rows and columns are present in the data.

df.shape
# Out:
# (292, 18)

# %%
# seeing all the columns mentioned in the data.

df.columns
# Out:
# Index(['track_name', 'artist_name', 'artist_pop', 'album', 'track_pop',
#        'danceability', 'energy', 'loudness', 'mode', 'key', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'duration_ms'],
#       dtype='object')

# %%
# checking the datatypes of the columns.

df.dtypes
# Out:
# track_name           object
# artist_name          object
# artist_pop            int64
# album                object
# track_pop             int64
# danceability        float64
# energy              float64
# loudness            float64
# mode                  int64
# key                   int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# duration_ms           int64
# dtype: object

# %%
#To get statistical information about numeric columns.

df.describe()
# Out:
#        artist_pop  track_pop  danceability      energy    loudness  \
# count  292.000000  292.00000    292.000000  292.000000  292.000000
# mean    67.318493   61.19863      0.725404    0.612855   -6.884469
# std     16.571140   20.78498      0.143129    0.163366    2.697198
# min      0.000000    0.00000      0.174000    0.045800  -23.928000
# 25%     57.750000   57.00000      0.651000    0.489250   -8.369750
# 50%     69.000000   66.00000      0.734500    0.631000   -6.523000
# 75%     80.000000   74.00000      0.831750    0.729000   -4.983500
# max     95.000000   90.00000      0.980000    0.955000   -2.607000
#
#              mode         key  speechiness  acousticness  instrumentalness  \
# count  292.000000  292.000000   292.000000    292.000000        292.000000
# mean     0.534247    5.041096     0.150245      0.232500          0.028654
# std      0.499682    3.689638     0.150504      0.255970          0.114149
# ...

# %%
# to see all the columns and their datatypes.
# by doing this we can correct columns.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_name        292 non-null    object
#  1   artist_name       292 non-null    object
#  2   artist_pop        292 non-null    int64
#  3   album             292 non-null    object
#  4   track_pop         292 non-null    int64
#  5   danceability      292 non-null    float64
#  6   energy            292 non-null    float64
#  7   loudness          292 non-null    float64
#  8   mode              292 non-null    int64
#  9   key               292 non-null    int64
#  10  speechiness       292 non-null    float64
#  11  acousticness      292 non-null    float64
#  12  instrumentalness  292 non-null    float64
#  13  liveness          292 non-null    float64
#  14  valence           292 non-null    float64
#  15  tempo             292 non-null    float64
# ...

# %%
#to check null values in columns.
df.isnull().sum()
# Out:
# track_name          0
# artist_name         0
# artist_pop          0
# album               0
# track_pop           0
# danceability        0
# energy              0
# loudness            0
# mode                0
# key                 0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# duration_ms         0
# dtype: int64

# %%
# Since there are no null-values, we can go ahead to the next step.

# %%
df.head()
# Out:
#                          track_name          artist_name  artist_pop  \
# 0                            Say So             Doja Cat          88
# 1                   Blinding Lights           The Weeknd          93
# 2  Supalonely (feat. Gus Dapperton)                BENEE          67
# 3                            Savage  Megan Thee Stallion          82
# 4                Moral of the Story                 Ashe          68
#
#                 album  track_pop  danceability  energy  loudness  mode  key  \
# 0            Hot Pink         80         0.787   0.673    -4.583     0   11
# 1         After Hours         90         0.514   0.730    -5.934     1    1
# 2             Hey u x         63         0.862   0.631    -4.746     1    7
# 3                Suga         70         0.843   0.741    -5.609     1   11
# 4  Moral of the Story         76         0.572   0.406    -8.624     1   10
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
# after understanding the columns, I want to convert "duration_ms" column to minutes.

# %%
df.duration_ms
# Out:
# 0      237893
# 1      200040
# 2      223488
# 3      155497
# 4      201084
#         ...
# 287    225560
# 288    211666
# 289    181733
# 290    195613
# 291    114660
# Name: duration_ms, Length: 292, dtype: int64

# %%
# the column is in milliseconds. To make my calculations easier, I will convert them into minutes.

# %%
df["duration_m"] = df["duration_ms"]/1000/60

# %%
df.duration_m
# Out:
# 0      3.964883
# 1      3.334000
# 2      3.724800
# 3      2.591617
# 4      3.351400
#          ...
# 287    3.759333
# 288    3.527767
# 289    3.028883
# 290    3.260217
# 291    1.911000
# Name: duration_m, Length: 292, dtype: float64

# %%
# we can now drop the duration_ms column.

# %%
df=df.drop('duration_ms',axis=1)

# %%
# Now we will check for outliers in the numeric columns columns.

# %%
df.head()
# Out:
#                          track_name          artist_name  artist_pop  \
# 0                            Say So             Doja Cat          88
# 1                   Blinding Lights           The Weeknd          93
# 2  Supalonely (feat. Gus Dapperton)                BENEE          67
# 3                            Savage  Megan Thee Stallion          82
# 4                Moral of the Story                 Ashe          68
#
#                 album  track_pop  danceability  energy  loudness  mode  key  \
# 0            Hot Pink         80         0.787   0.673    -4.583     0   11
# 1         After Hours         90         0.514   0.730    -5.934     1    1
# 2             Hey u x         63         0.862   0.631    -4.746     1    7
# 3                Suga         70         0.843   0.741    -5.609     1   11
# 4  Moral of the Story         76         0.572   0.406    -8.624     1   10
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'artist_name', 'artist_pop', 'album', 'track_pop',
#        'danceability', 'energy', 'loudness', 'mode', 'key', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'duration_ms', 'duration_m'],
#       dtype='object')

# %%
# artist_pop

# %%
sns.boxplot(df.artist_pop)
plt.show()

# %%
# there are a few artists who are less popular.

# %%
#track_pop

# %%
sns.boxplot(df.track_pop)
plt.show()

# %%
# there are many tracks which have less popularity.

# %%
#loudness

# %%
sns.boxplot(df.loudness)
plt.show()

# %%
#there are songs with very low sound.

# %%
#tempo

# %%
sns.boxplot(df.tempo)
plt.show()

# %%
#there are songs which have greater than 180 beats per minute.

# %%
#duration_m

# %%
sns.boxplot(df.duration_m)
plt.show()

# %%
# there are songs which are less than 1 minute, and there are songs which are greater than 6 minutes long.

# %%
df.to_csv('pre-placement.csv', index=False)

# %%
df.to_csv(r'DOWNLOADS\pre-placement.csv')
